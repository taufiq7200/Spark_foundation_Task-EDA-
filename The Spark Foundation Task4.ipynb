# %% [markdown]
# # The Spark Foundation
# ## GRIPNOV20
# ## Task 4
#
# ### EXPLORE DATA ANAYLIS using Terriosm dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# In this Task I Use global terrrirosm dataset to explore the data and exttract insight .

# %%
data = pd.read_csv('Global Torism_Data.csv' , encoding='latin1')
# Out:
# C:\Users\Taufiq\anaconda64\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (4,6,8,10,11,12,17,18,24,29,31,33,35,37,38,39,41,43,45,46,47,49,51,53,54,55,57,58,59,60,61,62,63,64,73,76,79,82,84,86,88,90,92,94,96,97,106,108,114,115,121,123,125,126,127,128,129,134) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#         eventid   iyear  imonth  iday approxdate  extended resolution  \
# 0  1.970000e+11  1970.0     7.0   2.0        NaN       0.0        NaN
# 1  1.970000e+11  1970.0     0.0   0.0        NaN       0.0        NaN
# 2  1.970000e+11  1970.0     1.0   0.0        NaN       0.0        NaN
# 3  1.970000e+11  1970.0     1.0   0.0        NaN       0.0        NaN
# 4  1.970000e+11  1970.0     1.0   0.0        NaN       0.0        NaN
#
#    country         country_txt  region  ... addnotes scite1 scite2  scite3  \
# 0     58.0  Dominican Republic     2.0  ...      NaN    NaN    NaN     NaN
# 1    130.0              Mexico     1.0  ...      NaN    NaN    NaN     NaN
# 2    160.0         Philippines     5.0  ...      NaN    NaN    NaN     NaN
# 3     78.0              Greece     8.0  ...      NaN    NaN    NaN     NaN
# 4    101.0               Japan     4.0  ...      NaN    NaN    NaN     NaN
#
#    dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
data.tail()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 196327      NaN    NaN     NaN   NaN        NaN       NaN        NaN      NaN
# 196328      NaN    NaN     NaN   NaN        NaN       NaN        NaN      NaN
# 196329      NaN    NaN     NaN   NaN        NaN       NaN        NaN      NaN
# 196330      NaN    NaN     NaN   NaN        NaN       NaN        NaN      NaN
# 196331      NaN    NaN     NaN   NaN        NaN       NaN        NaN      NaN
#
#        country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 196327         NaN     NaN  ...      NaN    NaN    NaN     NaN       NaN
# 196328         NaN     NaN  ...      NaN    NaN    NaN     NaN       NaN
# 196329         NaN     NaN  ...      NaN    NaN    NaN     NaN       NaN
# 196330         NaN     NaN  ...      NaN    NaN    NaN     NaN       NaN
# 196331         NaN     NaN  ...      NaN    NaN    NaN     NaN       NaN
#
#         INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196332 entries, 0 to 196331
# Columns: 135 entries, eventid to related
# dtypes: float64(77), object(58)
# memory usage: 202.2+ MB

# %%
data.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.797450e+05  179745.000000  179745.000000  179745.000000
# mean   2.003056e+11    2002.483518       6.416223      15.484642
# std    1.379895e+09      13.246091       3.369799       8.811636
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.990000e+11    1990.000000       4.000000       8.000000
# 50%    2.010000e+11    2008.000000       6.000000      15.000000
# 75%    2.010000e+11    2014.000000       9.000000      23.000000
# max    2.020000e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  179745.000000  179745.000000  179745.000000  175199.000000
# mean        0.045147     132.071657       7.151381      23.486873
# std         0.207628     112.478759       2.937103      18.619475
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
data.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.973631 -0.021157  0.014819  0.092256 -0.135343
# iyear      0.973631  1.000000 -0.016462  0.015863  0.091985 -0.135539
# imonth    -0.021157 -0.016462  1.000000  0.002979 -0.001882 -0.005172
# iday       0.014819  0.015863  0.002979  1.000000 -0.004622  0.003598
# extended   0.092256  0.091985 -0.001882 -0.004622  1.000000 -0.020920
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.182462 -0.185090 -0.012323  0.002488 -0.193652 -0.046659
# INT_LOG   -0.128618 -0.145788 -0.002969 -0.002006  0.071458  0.070554
# INT_IDEO  -0.118526 -0.135457 -0.002859 -0.002111  0.074888  0.068182
# INT_MISC  -0.082431 -0.078012 -0.002079 -0.001974  0.027635  0.207839
# INT_ANY   -0.160750 -0.177608 -0.006369 -0.001555  0.080649  0.154124
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
data.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.nkillus.plot(kind = 'line' , color = 'green' , label='Total confirmed fartelity in US' , linewidth=2 , alpha=0.8,linestyle=':' , figsize = (16,10) , fontsize=(4))

data.nwoundus.plot( color = 'blue' , label='Total confirmed non-fartelity in US' , linewidth=2 , alpha=0.8,linestyle='-.' , figsize = (16,10) , fontsize=(4))

plt.legend(loc ='upper right')
plt.xlabel('Database index',fontsize=6)
plt.ylabel('Death and Injuries' , fontsize=10)

plt.title('Fartelity vs non-fartelity')
plt.show()

# %%
data.plot(kind ='scatter' , x='nkill' , y='nwound' , alpha=0.5 , color='green' , figsize=(16,6) , fontsize=6)
plt.xlabel('KILLS' , fontsize=15)
plt.ylabel('wound' , fontsize=15)
plt.title('KILL - wound satter plot')
plt.show()

# %%
M_east_data = data[data['region'] == 10]
M_east_data.iyear.plot(kind ="hist" , bins= 30 , figsize=(16,6) , color='blue' )
plt.xlabel('YEAR' , fontsize=14)
plt.ylabel('frequency')
plt.title('middle east and north africa terriosm attack')
plt.show()

# %%
data.nkillus.plot(kind='line' , color='grey' , label='people Dead of terriosm in the world' , linewidth=3 , alpha=0.8 , linestyle=':' , figsize=(16,6) , fontsize=15)

M_east_data.nkillus.plot(kind='line' , color='green' , label='people Dead of terriosm in middle east and north africa' , linewidth=3 , alpha=0.8 , linestyle='-.' , figsize=(16,6) , fontsize=15)

plt.legend(loc='upper right')
plt.xlabel('Database Index' , fontsize=15)
plt.ylabel('Number of Dead' , fontsize=15)
plt.title('comparing terro attack in all our world and middle east and north africa')
plt.show()

# %%
filterYear = data['iyear']  ==1970

# %%
filterData = data[filterYear]

reqfilterData = filterData.loc[: ,'city':'longitude']
reqfilterData = reqfilterData.dropna()
reqfilterDataList = reqfilterData.values.tolist()

# %%
killData = data.loc[:,'nkill']
print('Number of people killed by terror attck:' , int(sum(killData.dropna())))
# Out:
# Number of people killed by terror attck: 407500

# %%
attack_data = data.loc[:,'attacktype1':'attacktype1_txt']

type_killdata = pd.concat([attack_data , killData], axis=1)

# %%
type_kill_format_data = type_killdata.pivot_table(columns='attacktype1_txt' , values='nkill' , aggfunc='sum')
type_kill_format_data
# Out:
# attacktype1_txt  Armed Assault  Assassination  Bombing/Explosion  \
# nkill                 159240.0        24746.0           155319.0
#
# attacktype1_txt  Facility/Infrastructure Attack  Hijacking  \
# nkill                                    3627.0     3718.0
#
# attacktype1_txt  Hostage Taking (Barricade Incident)  \
# nkill                                         4408.0
#
# attacktype1_txt  Hostage Taking (Kidnapping)  Unarmed Assault  Unknown
# nkill                                24007.0            871.0  31564.0

# %%
type_kill_format_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, nkill to nkill
# Data columns (total 9 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Armed Assault                        1 non-null      float64
#  1   Assassination                        1 non-null      float64
#  2   Bombing/Explosion                    1 non-null      float64
#  3   Facility/Infrastructure Attack       1 non-null      float64
#  4   Hijacking                            1 non-null      float64
#  5   Hostage Taking (Barricade Incident)  1 non-null      float64
#  6   Hostage Taking (Kidnapping)          1 non-null      float64
#  7   Unarmed Assault                      1 non-null      float64
#  8   Unknown                              1 non-null      float64
# dtypes: float64(9)
# memory usage: 80.0+ bytes

# %%
labels = type_kill_format_data.columns.tolist()
transpose = type_kill_format_data.T
values= transpose.values.tolist()
fig , ax = plt.subplots(figsize=(20,20) , subplot_kw=dict(aspect='equal'))
plt.pie(values , startangle=90 , autopct='%.2f%%')
plt.title('Types of terrorist attack')
plt.legend(labels , loc="upper right" , bbox_to_anchor = (1.3 , 0.9) , fontsize=15)
plt.show()
# Out:
# <ipython-input-45-22ae08976120>:5: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   plt.pie(values , startangle=90 , autopct='%.2f%%')

# %% [markdown]
# 1. In above graph shows that highest attack is armed assult. there is 39.09% of all our attck.
# 2. and the second largest attack on BOMBING AND EXPLOSION.
# 3. and less attack on infrastuture attack.

# %%
country_data = data.loc[: , 'country':'country_txt']

country_killdata = pd.concat([country_data , killData] , axis=1)

# %%
country_kill_format_data = country_killdata.pivot_table(columns='country_txt' , values='nkill' , aggfunc='sum')
country_kill_format_data
# Out:
# country_txt  Afghanistan  Albania  Algeria  Andorra  Angola  \
# nkill            38062.0     42.0  11066.0      0.0  3043.0
#
# country_txt  Antigua and Barbuda  Argentina  Armenia  Australia  Austria  ...  \
# nkill                        0.0      490.0     37.0       22.0     30.0  ...
#
# country_txt  Vietnam  Wallis and Futuna  West Bank and Gaza Strip  \
# nkill            1.0                0.0                    1496.0
#
# country_txt  West Germany (FRG)  Western Sahara   Yemen  Yugoslavia  Zaire  \
# nkill                      97.0             1.0  8559.0       119.0  324.0
#
# country_txt  Zambia  Zimbabwe
# nkill          70.0     154.0
#
# [1 rows x 205 columns]

# %%
country_kill_format_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, nkill to nkill
# Columns: 205 entries, Afghanistan to Zimbabwe
# dtypes: float64(205)
# memory usage: 1.6+ KB

# %%
fig_size = plt.rcParams['figure.figsize']
fig_size[0]=25
fig_size[1]=25
plt.rcParams['figure.figsize'] = fig_size

# %%
labels = country_kill_format_data.columns.tolist()
labels = labels[:50]
index = np.arange(len(labels))
transpose = country_kill_format_data.T
values = transpose.values.tolist()
values = values[:50]
values = [int(i[0]) for i in values]
colors = ['red' , 'blue' , 'green' , 'grey' , 'black' , 'brown' ,'magenta' , 'orange']
fig , ax = plt.subplots(1,1)
ax.yaxis.grid(True)
fig_size = plt.rcParams['figure.figsize']
fig_size[0]=25
fig_size[1]=25
plt.rcParams['figure.figsize'] = fig_size
plt.bar(index , values , color=colors , width=0.9)
plt.ylabel('killes peaple' , fontsize=15)
plt.xticks(index , labels , fontsize=14 , rotation=90)
plt.title('Number of people killed by countries')
plt.show()

# %% [markdown]
# 1. Afghanistan,algeria,colombia are country has more attack due to this there are more people die on this country.
# 2. Beliza,Bruncie,cuba,East Timor that country had less attack or says no attack that why those country died ration is very less.

# %%
labels = country_kill_format_data.columns.tolist()
labels = labels[50:101]
index = np.arange(len(labels))
transpose = country_kill_format_data.T
values = transpose.values.tolist()
values = values[50:101]
values = [int(i[0]) for i in values]
colors = ['red' ,'yellow', 'blue' , 'green' , 'grey' , 'black' , 'brown' ,'magenta' , 'orange']
fig , ax = plt.subplots(1,1)
ax.yaxis.grid(True)
fig_size = plt.rcParams['figure.figsize']
fig_size[0]=25
fig_size[1]=25
plt.rcParams['figure.figsize'] = fig_size
plt.bar(index , values , color=colors , width=0.9)
plt.ylabel('killes peaple' , fontsize=15)
plt.xticks(index , labels , fontsize=14 , rotation=90)
plt.title('Number of people killed by countries')
plt.show()

# %%
labels = country_kill_format_data.columns.tolist()
labels = labels[101:201]
index = np.arange(len(labels))
transpose = country_kill_format_data.T
values = transpose.values.tolist()
values = values[101:201]
values = [int(i[0]) for i in values]
colors = ['red' ,'yellow', 'blue' , 'green' , 'grey' , 'black' , 'brown' ,'magenta' , 'orange']
fig , ax = plt.subplots(1,1)
ax.yaxis.grid(True)
fig_size = plt.rcParams['figure.figsize']
fig_size[0]=25
fig_size[1]=25
plt.rcParams['figure.figsize'] = fig_size
plt.bar(index , values , color=colors , width=0.9)
plt.ylabel('killes peaple' , fontsize=15)
plt.xticks(index , labels , fontsize=14 , rotation=90)
plt.title('Number of people killed by countries')
plt.show()

# %%
labels = country_kill_format_data.columns.tolist()
labels = labels[201:301]
index = np.arange(len(labels))
transpose = country_kill_format_data.T
values = transpose.values.tolist()
values = values[201:301]
values = [int(i[0]) for i in values]
colors = ['red' ,'yellow', 'blue' , 'green' , 'grey' , 'black' , 'brown' ,'magenta' , 'orange']
fig , ax = plt.subplots(1,1)
ax.yaxis.grid(True)
fig_size = plt.rcParams['figure.figsize']
fig_size[0]=25
fig_size[1]=25
plt.rcParams['figure.figsize'] = fig_size
plt.bar(index , values , color=colors , width=0.9)
plt.ylabel('killes peaple' , fontsize=15)
plt.xticks(index , labels , fontsize=14 , rotation=90)
plt.title('Number of people killed by countries')
plt.show()
